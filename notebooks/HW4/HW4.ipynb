# %% [markdown]
# # HW4
#
# Welcome to HW4!
#
# ## Notebook setup

# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]
import seaborn as sns
import pandas as pd

# 3d figures
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# creating animations
import matplotlib.animation
from IPython.display import HTML

# styling additions
from IPython.display import HTML
style = '''
    <style>
        div.info{
            padding: 15px; 
            border: 1px solid transparent; 
            border-left: 5px solid #dfb5b4; 
            border-color: transparent; 
            margin-bottom: 10px; 
            border-radius: 4px; 
            background-color: #fcf8e3; 
            border-color: #faebcc;
        }
        hr{
            border: 1px solid;
            border-radius: 5px;
        }
    </style>'''
HTML(style)
# Out:
#     <style>
#         div.info{
#             padding: 15px;
#             border: 1px solid transparent;
#             border-left: 5px solid #dfb5b4;
#             border-color: transparent;
#             margin-bottom: 10px;
#             border-radius: 4px;
#             background-color: #fcf8e3;
#             border-color: #faebcc;
#         }
#         hr{
#             border: 1px solid;
#             border-radius: 5px;
#         }
#     </style>

# %% [markdown]
# ## Assignment Outline
#
# <div class='alert alert-block alert-danger'>
#
# <font size='5'>🗓</font> **Due: This assignment is due Sunday 5/1/22 at 11:59 PM.**
#
# </div>
#
#
# For this homework you only need turn in this notebook. To do so, you will submit **two files**:
# - the original `.ipynb`
# - a PDF of the file
#
# So in total, you will turn in **2 files**.

# %% [markdown]
# # Problem 1 - Decision Trees/Random Forests

# %% [markdown]
# This problem will use two extra packages to make some nice visualizations of our trees!
#
# **Uncommment and run this cell to install these packages:**

# %%
# !pip install dtreeviz

# %%
import dtreeviz
from dtreeviz import clfviz

# %% [markdown]
# Now we're ready. Lets start with the **wine** dataset we used in class:

# %%
from sklearn.datasets import load_wine

# %%
wine = load_wine()
X = wine.data

# %%
X.shape
# Out:
# (178, 13)

# %% [markdown]
# This dataset has 13 features:

# %%
wine.feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# Lets pick a subset for easy plotting:

# %%
X = X[:,[12,6]]
y = wine.target

# %% [markdown]
# Now we're ready!

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_leaf=20, n_jobs=-1)
rf.fit(X, y)

fig,axes = plt.subplots(1,1,dpi=300)
clfviz(rf, X, y, ax=axes,
       # show classification regions not probabilities
       show=['instances', 'boundaries', 'misclassified'], 
       feature_names=['proline', 'flavanoid']);

# %% [markdown]
# <br/>
# <div class='info'>
#
# <font size='5'>🤔</font> **Pause-and-Ponder:** Below, regenerate the above analysis for different values of:
#
# - `min_samples_leaf`
# - `max_depth`
# - `n_estimators`
#
# Investigate their effect on the decision boundary!
#
# </div>

# %%
# EDIT HERE

# %%
# EDIT HERE

# %%
# EDIT HERE

# %% [markdown]
# <br/>
# <div class='info'>
#
# <font size='5'>🤔</font> **Pause-and-Ponder:**  After completing the above analysis, write your observations below! Give a well thought-out answer here!
#
# </div>
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Problem 2 - PCA
#
# For this problem, run PCA on the **full** wine dataset we imported above!

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# <br/>
# <div class='info'>
#
# <font size='5'>💻</font> **Code-it-up:** As we did in class, code up a run of PCA on the wine dataset and show
#
# - a plot of dataset on the 2 principle components
#  - **hint**: use the `.fit_transform()` method to project your dataset onto the components!
# - a plot of the explained variance ratio for all components
#
# </div>

# %%
# EDIT HERE

# %%
# EDIT HERE

# %%
# EDIT HERE

# %% [markdown]
# <br/>
# <div class='info'>
#
# <font size='5'>🤔</font> **Pause-and-Ponder:**  Comment below on the quality of the fit! How did PCA do on this dataset? Give a good answer here!
#
# </div>
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Problem 3 - KMeans

# %% [markdown]
# For this problem run a K-Means on the **result of your PCA dimensionality reduced data** for the following:
# - 2 components
# - 5 components
# - 10 components
#
# **And give the three plots!**
#
# **Note:** I have intentionally not given you a code example for this problem! Try reading the documentation and use what we currently know to see how to specify a KMeans yourself!
#
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %%
# EDIT HERE

# %%
# EDIT HERE

# %%
# EDIT HERE
